# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

# %%
audio_file_path = '/Users/siyeon/Downloads/lsy_audio_2023_58s.mp3'

with open(audio_file_path, 'rb') as audio_file:
    transcription = client.audio.translations.create(
        model='whisper-1',
        file=audio_file
    )

transcription
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 audio_file_path = '/Users/siyeon/Downloads/lsy_audio_2023_58s.mp3'
#       3 with open(audio_file_path, 'rb') as audio_file:
# ----> 4     transcription = client.audio.translations.create(
#       5         model='whisper-1',
#       6         file=audio_file
#       7     )
#       9 transcription
#
# NameError: name 'client' is not defined
